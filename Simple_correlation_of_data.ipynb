# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
# %matplotlib notebook

# %% [markdown]
# # Datos
# Obtenga los datos y convierte las columnas necesarias

# %% [markdown]
# ## Usando como creferencia el numero de personas habilitadas para votar

# %%
municipios_y_victimas = pickle.load(open('./plebicito_municipios_y_victimas20161010.pickle', 'rb'))

# %%
municipios_y_victimas['CocienteSi'] = municipios_y_victimas['Si']/municipios_y_victimas['habilitados'] 
municipios_y_victimas['CocienteNo'] = municipios_y_victimas['No']/municipios_y_victimas['habilitados'] 
municipios_y_victimas['CocienteVictimas'] = municipios_y_victimas['TOTAL']/municipios_y_victimas['habilitados']
slope_si, intercept_si, r_si, p_si, stderr_si = linregress(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteSi'])
slope, intercept, r, p, stderr = linregress(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteNo'])

# %%
fig, ax = plt.subplots(1,1)
ax.plot(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteSi'], 's', label='votos Si')
ax.plot(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteNo'], 'x', label='votos No')
ax.set_xlabel('# de victimas / # de personas habilitadas para votar')
ax.set_ylabel('votos (no/si)/ # de personas habilitadas para votar')
x = np.linspace(*ax.axis()[0:2], 10)
ax.plot(x, slope_si*x+intercept_si, linestyle='dotted', label='regresion Si')
ax.plot(x, slope*x+intercept, linestyle='dotted', label='regresion No')

ax.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plt.subplots(1,1)
ax.semilogx(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteSi'], 's', label='votos Si')
ax.semilogx(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteNo'], 'x', label='votos No')
ax.set_xlabel('# de victimas / # de personas habilitadas para votar')
ax.set_ylabel('votos (no/si)/ # de personas habilitadas para votar')
ax.legend(loc=3)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Usando como referencia el numero de personas que votan

# %%
municipios_y_victimas['CocienteSi'] = municipios_y_victimas['Si']/municipios_y_victimas['total votos'] 
municipios_y_victimas['CocienteNo'] = municipios_y_victimas['No']/municipios_y_victimas['total votos'] 
municipios_y_victimas['CocienteVictimas'] = municipios_y_victimas['TOTAL']/municipios_y_victimas['total votos']
slope_si, intercept_si, r_si, p_si, stderr_si = linregress(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteSi'])
slope, intercept, r, p, stderr = linregress(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteNo'])

# %%
fig, ax = plt.subplots(1,1)
ax.plot(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteSi'], 's', label='votos Si')
ax.plot(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteNo'], 'x', label='votos No')
slope_si, intercept_si, r_si, p_si, stderr_si = linregress(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteSi'])
x = np.linspace(*ax.axis()[0:2], 10)
ax.plot(x, slope_si*x+intercept_si, linestyle='dotted', label='regresion Si')
x = np.linspace(*ax.axis()[0:2], 10)
ax.plot(x, slope*x+intercept, linestyle='dotted', label='regresion No')
ax.set_xlabel('# de victimas / # numero de votos validos')
ax.set_ylabel('votos (no/si)/ # numero de votos validos')
ax.set_title('slope: {:0.2f}, stderr: {:0.4f}, pvalue: {:1.3e}'.format(slope_si, stderr_si, p_si))
ax.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plt.subplots(1,1)
ax.semilogx(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteSi'], 's', label='votos Si')
ax.semilogx(municipios_y_victimas['CocienteVictimas'], municipios_y_victimas['CocienteNo'], 'x', label='votos No')
ax.set_xlabel('# de victimas / # de personas habilitadas para votar')
ax.set_ylabel('votos (no/si)/ # de personas habilitadas para votar')
ax.legend(loc=0)
# Out:
# <img src="data:image/png;base64,...">
